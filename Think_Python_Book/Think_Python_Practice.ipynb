# %%
"""Important files and modules to always download and import first"""
import os
from os.path import basename, exists
from urllib.request import urlretrieve

def download(url, download_dir=None):
    filename = basename(url)
    # If download_dir is specified, create the full path
    if download_dir:
        # Create a directory if it doesn't exist
        os.makedirs(download_dir, exist_ok=True) 
        full_path = os.path.join(download_dir, filename)
    else:
        full_path = filename
    
    # If the file doesn't exist
    if not exists(full_path):
        local, _ = urlretrieve(url, full_path)
        print("Downloaded " + str(local))
    return full_path

python_practice_path = "C:\\Users\\USUARIO\\OneDrive\\Documentos\\My_Projects\\Projects\\Python_Practice\\Files\\Think_Python_Files"
download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py', python_practice_path);
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py', python_practice_path);
download('https://github.com/ramalho/jupyturtle/releases/download/2024-03/jupyturtle.py', python_practice_path);

import thinkpython
# Out:
# Downloaded C:\Users\USUARIO\OneDrive\Documentos\My_Projects\Projects\Python_Practice\Files\Think_Python_Files\thinkpython.py
# Downloaded C:\Users\USUARIO\OneDrive\Documentos\My_Projects\Projects\Python_Practice\Files\Think_Python_Files\diagram.py
# Downloaded C:\Users\USUARIO\OneDrive\Documentos\My_Projects\Projects\Python_Practice\Files\Think_Python_Files\jupyturtle.py

# %% [markdown]
# # Chapter 1: Programming As A Way Of Thinking
# ## Exercise 1
# You might wonder what `round` does if a number ends in `0.5`.
# The answer is that it sometimes rounds up and sometimes rounds down.
# Try these examples and see if you can figure out what rule it follows.
# * `42.5`
# * `43.5`

# %%
"""Exercise 1: Answer"""
N1 = round(42.5)
N2 = round(43.5)
print("These are the numbers with round applied:", 
      f"\n42,5 = {N1}", 
      f"\n43,5 = {N2}")
# Out:
# These are the numbers with round applied:
# 42,5 = 42
# 43,5 = 44

# %% [markdown]
# ## Exercise 2
# Recall that every expression has a value, every value has a type, and we can use the `type` function to find the type of any value. What is the type of the value of the following expressions? Make your best guess for each one, and then use `type` to find out.
#
# * `765`
#
# * `2.718`
#
# * `'2 pi'`
#
# * `abs(-7)`
#
# * `abs(-7.0)`
#
# * `abs`
#
# * `int`
#
# * `type`

# %%
"""Exercise 2: Answer"""
t765 = type(765)
t2718 = type(2.718)
t_str = type('2 pi')
t_abs1 = type(abs(-7))
t_abs2 = type(abs(-7.0))
t_abs3 = type(abs)
t_int = type(int)
t_type = type(type)

# Answers
print(f"765 = {t765}",
      f"\n2.718 = {t2718}", 
      f"\n'2 pi = {t_str}", 
      f"\nabs(-7) = {t_abs1}", 
      f"\nabs(-7.0) = {t_abs2}", 
      f"\nabs = {t_abs3}", 
      f"\nint = {t_int}", 
      f"\ntype = {t_type}")
# Out:
# 765 = <class 'int'>
# 2.718 = <class 'float'>
# '2 pi = <class 'str'>
# abs(-7) = <class 'int'>
# abs(-7.0) = <class 'float'>
# abs = <class 'builtin_function_or_method'>
# int = <class 'type'>
# type = <class 'type'>

# %% [markdown]
# ## Exercise 3
# The following questions give you a chance to practice writing arithmetic expressions.
#
# 1.  How many seconds are there in 42 minutes 42 seconds?
# 2.  How many miles are there in 10 kilometers? Hint: there are 1.61 kilometers in a mile.
# 3.  If you run a 10 kilometer race in 42 minutes 42 seconds, what is your average pace in seconds per mile?
# 4.  What is your average pace in minutes and seconds per mile?
# 5.  What is your average speed in miles per hour?

# %%
"""Exercise 3: Answer"""
# Q1
def min_to_sec(n):
    return n * 60
minutes = min_to_sec(42)
seconds = minutes + 42
print(f"There are {seconds} seconds in 42 minutes and 42 seconds")

# Q2
kilometer = 10
miles = kilometer * 0.621371
print(f"There are {miles:.2f} miles in 10 kilometers")

# Q3
race_pace_seconds = seconds / kilometer  # seconds per km (float)
# Convert to minutes and seconds for nicer display
per_km_minutes = int(race_pace_seconds // 60)
per_km_seconds = int(race_pace_seconds % 60)
print(f"The race pace of 10Km in 42 minutes and 42 seconds is {per_km_minutes}:{per_km_seconds:02d} minutes per kilometer")

# Q4
race_pace_miles = seconds // miles
per_miles_minutes = int(per_km_minutes * 0.621371)
per_miles_seconds = int(per_miles_minutes % 60)
print(f"The race pace of {miles:.2f} miles in 42 minutes and 42 seconds is {per_miles_minutes}:{per_miles_seconds:02d} minutes per mile")

# Q5
avg_speed = 60 // per_miles_minutes
print(f"The average speed is {avg_speed} miles per hour")
# Out:
# There are 2562 seconds in 42 minutes and 42 seconds
# There are 6.21 miles in 10 kilometers
# The race pace of 10Km in 42 minutes and 42 seconds is 4:16 minutes per kilometer
# The race pace of 6.21 miles in 42 minutes and 42 seconds is 2:02 minutes per mile
# The average speed is 30 miles per hour

# %% [markdown]
# # Chapter 2: Variables and Statements
# ## Exercise 1
# The volume of a sphere with radius  r  is  4/3πr**3 . What is the volume of a sphere with radius 5? Start with a variable named radius and then assign the result to a variable named volume. Display the result. Add comments to indicate that radius is in centimeters and volume in cubic centimeters.

# %%
"""Exercise 1: Answer"""
import math
sphere_radius = 5 # In centimeters.
sphere_volume = ((4/3) * math.pi * (sphere_radius ** 3)) # In cubic centimeters.
print(f"The volume of a sphere where radius is {sphere_radius}cm is equal to {sphere_volume:.2f} cubic centimeters")
# Out:
# The volume of a sphere where radius is 5cm is equal to 523.60 cubic centimeters

# %%
def calculate_sphere_volume():
    """Prompt for a sphere radius (cm), validate it and return the volume (cm^3).

    Returns:
        float: The computed volume, or None if input is invalid.
    """
    try:
        # Get radius from user input.
        sphere_radius = float(input("Enter the radius of the sphere (cm): "))  # In centimeters
    except ValueError:
        print("Error: please enter a numeric value for the radius.")
        return None

    # Check for negative radius.
    if sphere_radius < 0:
        print("Error: radius cannot be negative")
        return None

    # Calculate the volume (math is imported in another cell).
    sphere_volume = (4 / 3) * math.pi * (sphere_radius ** 3)  # In cubic centimeters.

    # Display results.
    print(f"\nThe sphere radius is: {sphere_radius} centimeters")
    print(f"The sphere volume is: {sphere_volume:.2f} cubic centimeters")

calculate_sphere_volume()
# Out:
# The sphere radius is: 5.0 centimeters
# The sphere volume is: 523.60 cubic centimeters

# %% [markdown]
# ## Exercise 2
# A rule of trigonometry says that for any value of  x ,  (cosx)2+(sinx)2=1 . Let's see if it's true for a specific value of  x  like 42.
#
# Create a variable named x with this value. Then use math.cos and math.sin to compute the sine and cosine of  x , and the sum of their squared.
#
# The result should be close to 1. It might not be exactly 1 because floating-point arithmetic is not exact---it is only approximately correct.

# %%
"""Exercise 2: Answer"""
def calculate_t_rule():
    try:
        x = float(input("Insert X value: "))
    except ValueError:
            print("Error: please enter a numeric value for the radius.")
            return None
    
    # Calculate cosine and sine of x
    cos_x = math.cos(x)
    sin_x = math.sin(x)

    # Calculate the sum of (sinx) and (cosx) squared.
    t_rule = (cos_x ** 2) + (sin_x ** 2)

    # Display result
    print(f"X = {x}")
    print(f"Cosine of x is {cos_x:.2f}")
    print(f"Sine of x is {sin_x:.2f}")
    print(f"The result of (cosx)2 + (sinx)2 is {t_rule:.2f}")

calculate_t_rule()
# Out:
# X = 14.0
# Cosine of x is 0.14
# Sine of x is 0.99
# The result of (cosx)2 + (sinx)2 is 1.00

# %% [markdown]
# ## Exercise 3
# In addition to pi, the other variable defined in the math module is e, which represents the base of the natural logarithm, written in math notation as  e . If you are not familiar with this value, ask a virtual assistant "What is math.e?" Now let's compute  e2  three ways:
#
# * Use math.e and the exponentiation operator (**).
#
# * Use math.pow to raise math.e to the power 2.
#
# * Use math.exp, which takes as an argument a value,  x , and computes  ex .
#
# You might notice that the last result is slightly different from the other two. See if you can find out which is correct.

# %%
"""Exercise 3: Answer"""
exe1 = math.e ** 2
exe2 = math.pow(math.e, 2)
exe3 = math.exp(2)

# Answers to the 3 options to square e.
print(f"First option: {exe1:.2f}")
print(f"Second option: {exe2:.2f}")
print(f"Third option: {exe3:.2f}")
# Out:
# First option: 7.39
# Second option: 7.39
# Third option: 7.39

# %% [markdown]
# # Chapter 3: Functions
# ## Exercise 1
# Write a function named `print_right` that takes a string named `text` as a parameter and prints the string with enough leading spaces that the last letter of the string is in the 40th column of the display.
#
# Hint: Use the len function, the string concatenation operator (+) and the string repetition operator (*).

# %%
"""Exercise 1"""
def print_right(text):
    text_length = len(text)
    space = 40 - text_length
    print(" " * space, text)

# %%
"""Test Exerceise 1: Solution"""
print_right("Monty")
print_right("Python's")
print_right("Flying Circus")
# Out:
#                                     Monty
#                                  Python's
#                             Flying Circus

# %% [markdown]
# ## Exercise 2
# Write a function called triangle that takes a string and an integer and draws a pyramid with the given height, made up using copies of the string.

# %%
"""Exercise 2: Solution"""
def triangle(string, n):
    # iterate from 1 to n (inclusive) to build the pyramid of given height
    for i in range(1, n + 1):
        print(string * i)

# %%
"""Test Exercise 2"""
triangle('L', 5)
# Out:
# L
# LL
# LLL
# LLLL
# LLLLL

# %% [markdown]
# ## Exercise 3
# Write a function called `rectangle` that takes a string and two integers and draws a rectangle with the given width and height, made up using copies of the string. Here's an example of a rectangle with width `5` and height `4`, made up of the string `'H'`.

# %%
"""Exercise 3: Solution"""
def rectangle(string, width, height):
    print(string * width)
    for i in range(height-2):
        middle_space = " " * (width - 2)
        print(string + middle_space + string)
    print(string * width)

# %%
"""Test Exercise 3"""
rectangle("H", 10, 5)
# Out:
# HHHHHHHHHH
# H        H
# H        H
# H        H
# HHHHHHHHHH

# %% [markdown]
# ## Exercise 4
# The song "99 Bottles of Beer" starts with this verse:
#
# > 99 bottles of beer on the wall
# > 99 bottles of beer
# > Take one down, pass it around
# > 98 bottles of beer on the wall
#
# Then the second verse is the same, except that it starts with 98 bottles and ends with 97. The song continues -- for a very long time -- until there are 0 bottles of beer.
#
# Write a function called `bottle_verse` that takes a number as a parameter and displays the verse that starts with the given number of bottles.
#
# Hint: Consider starting with a function that can print the first, second, or last line of the verse, and then use it to write `bottle_verse`.

# %%
"""Exercise 4: Solution"""
def lines1_2(n):
    bottle_word = "bottle" if n == 1 else "bottles"
    print(f"{n} {bottle_word} of beer on the wall")
    print(f"{n} {bottle_word} of beer")
    print("Take one down, pass it arround")

def bottle_verse(n):
    for i in range(n, -1, -1):
        if i > 0:
            lines1_2(i)
            next_bottles = i - 1
            next_word = "bottle" if n == 1 else "bottles"
            if next_bottles == 0:
                print("No more bottles on the wall")
            else:    
                print(f"{next_bottles} {next_word} of beer on the wall")
                print()
        else:
            print()
            print("No more bottles of beer on the wall")
            print("No more bottles of beer")
            print("Go to the store and buy some more")
#            print("99 bottles of beer on the wall")

bottle_verse(3)
# Out:
# 3 bottles of beer on the wall
# 3 bottles of beer
# Take one down, pass it arround
# 2 bottles of beer on the wall
#
# 2 bottles of beer on the wall
# 2 bottles of beer
# Take one down, pass it arround
# 1 bottles of beer on the wall
#
# 1 bottle of beer on the wall
# 1 bottle of beer
# Take one down, pass it arround
# No more bottles on the wall
#
# No more bottles of beer on the wall
# No more bottles of beer
# Go to the store and buy some more

# %% [markdown]
# # File import codes

# %%
import sys
import importlib.util

# Path from pc
module_path1 = "C:\\Users\\USUARIO\\OneDrive\\Documentos\\My_Projects\\Projects\\Python_Practice\\Files\\Think_Python_Files\\thinkpython.py"
module_path2 = "C:\\Users\\USUARIO\\OneDrive\\Documentos\\My_Projects\\Projects\\Python_Practice\\Files\\Think_Python_Files\\jupyturtle.py"

# Create a module specification
spec1 = importlib.util.spec_from_file_location("thinkpython", module_path1)
spec2 = importlib.util.spec_from_file_location("jupyturtle", module_path2)

# Create modules from specification
module1 = importlib.util.module_from_spec(spec1)
module2 = importlib.util.module_from_spec(spec2)

# Add to sys.modules
sys.modules["thinkpython"] = module1
sys.modules["jupyturtle"] = module2

# Execute the module
spec1.loader.exec_module(module1)
spec2.loader.exec_module(module2)

import thinkpython
import jupyturtle

# %%
import os

p = "C:\\Users\\USUARIO\\OneDrive\\Documentos\\My_Projects\\Projects\\Python_Practice\\Files\\Think_Python_Files"

def import_module(module, directory_path):
    # Build the complete file path
    m_path = os.path.join(directory_path, f"{module}.py")
    
    # Check if file path exists
    if not os.path.exists(m_path):
        print(f"Error: File does not exist")
        return None
    
    # Create a spec from complete file path
    m_spec = importlib.util.spec_from_file_location(module, m_path)
    if m_spec is None:
        print(f"Could not create a spec for module {m_path}")
        return None
    
    # Create and execute module
    m_odule = importlib.util.module_from_spec(m_spec)
    sys.modules[module] = m_odule
    m_spec.loader.exec_module(m_odule)
    print(f"{module} loaded and ready to import")
    return m_odule

import_module("diagram", p)
# Out:
# diagram loaded and ready to import
# <module 'diagram' from 'C:\\Users\\USUARIO\\OneDrive\\Documentos\\My_Projects\\Projects\\Python_Practice\\Files\\Think_Python_Files\\diagram.py'>

# %% [markdown]
# # Chapter 4: Functions and Interfaces
# ## Exercise 1
# Write a function called `rectangle` that draws a rectangle with given side lengths.
# For example, here's a rectangle that's `80` units wide and `40` units tall.

# %%
from jupyturtle import forward, left, right, penup, pendown, make_turtle

"""Exercise 1 Solution"""
def rectangle(width, length):
    forward(width)
    left(90)
    forward(length)
    left(90)
    forward(width)
    left(90)
    forward(length)

# %%
"""Exercise 1 Test"""
make_turtle()
rectangle(width=90, length=30)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="240.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="240.0" y1="75.0" x2="240.0" y2="45.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="240.0" y1="45.0" x2="150.0" y2="45.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="45.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(0.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Exercise 2
# Write a function called `rhombus` that draws a rhombus with a given side length and a given interior angle. For example, here's a rhombus with side length `50` and an interior angle of `60` degrees.

# %%
"""Exercise 2 Solution"""

def rhombus(length, angle):
    angle2 = 180 - angle
    forward(length)
    left(angle)
    forward(length)
    left(angle2)
    forward(length)
    left(angle)
    forward(length)

# %%
"""Exercise 2 Test"""
make_turtle()
rhombus(40, 60)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="210.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.0" y1="40.4" x2="170.0" y2="40.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="40.4" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(30.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Exercise 3
# Now write a more general function called `parallelogram` that draws a quadrilateral with parallel sides. Then rewrite `rectangle` and `rhombus` to use `parallelogram`.

# %%
"""Exercise 3 Solution"""

# Define the function paralelogram
def parallelogram(length, width, angle):
    """Create a 4 sided parallelogram.
    The function takes the length, width and one of the angles as parameters.
    
    length = size of top and bottom borders
    width = size of side borders
    angle = in degrees"""
    angle2 = 180 - angle
    forward(length)
    left(angle)
    forward(width)
    left(angle2)
    forward(length)
    left(angle)
    forward(width)

# Define the function rectangle
def rectangle(length, width):
    """Create a rectangle using the parallelogram function.
    The function takes the length and width as parameters."""
    angle = 90
    parallelogram(length, width, angle)

# Define the function rhombus
def rhombus(length, angle):
    """Create a rhombus using the parallelogram function.
    The function takes the length and one of the angles as parameters."""
    width = length
    angle2 = 180 - angle
    parallelogram(length, width, angle)

# Define the function jump
def jump(distance):
    """Move the turtle without drawing.
    The function takes the distance as parameter."""
    penup()
    forward(distance)
    pendown()

# %%
"""Exercise 3 Test"""
make_turtle(width=500, delay=0.2)
jump(-200)

rectangle(80, 40)
left(90)
jump(100)
rhombus(50, 60)
left(120)
jump(80)
parallelogram(80, 50, 60)
# Out:
# <svg width="500" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="50.0" y1="75.0" x2="130.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="75.0" x2="130.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.0" y1="35.0" x2="50.0" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="50.0" y1="35.0" x2="50.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="200.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="75.0" x2="225.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="225.0" y1="31.7" x2="175.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="175.0" y1="31.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="75.0" x2="310.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="310.0" y1="75.0" x2="335.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="335.0" y1="31.7" x2="255.0" y2="31.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="255.0" y1="31.7" x2="230.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(30.0,230.0,75.0) translate(230.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Exercise 4
# Write an appropriately general set of functions that can draw shapes like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_pie.png)
#
# Hint: Write a function called `triangle` that draws one triangular segment, and then a function called `draw_pie` that uses `triangle`.

# %%
"""Exercise 4 Solution"""
def triangle(length, angle):
    forward(length)
    left(angle)
    forward(length)
    left(angle)
    forward(length)

# %%
"""Exercise 4 Test"""
from jupyturtle import make_turtle, forward, left, right
import math

def pie(length, sides):
    angle = 360 / sides
    radius = length / (2 * math.sin(math.pi / sides))  # distance from center to vertex

    # Draw pie lines from center to vertices
    for _ in range(sides):
        forward(radius)
        left(180)
        forward(radius)
        left(180 - angle)

    # Draw the polygon around the pie
    forward(radius)  # move to first vertex
    left(180 - ((180 * (sides - 2)) / (2 * sides)))  # orient correctly to draw polygon
    polygon_side = 2 * radius * math.sin(math.pi / sides)
    for _ in range(sides):
        forward(polygon_side)
        left(angle)

    # Move to the side for next shape
    right(123)
    jump(3 * length)
 #   left(90)

def draw_all():
#    make_turtle(delay=0.05)
    for sides in [5, 6, 7]:
        pie(40, sides)
make_turtle(width=500, delay=0.05)
jump (-170)
draw_all()
# Out:
# <svg width="500" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="80.0" y1="75.0" x2="114.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.0" y1="75.0" x2="80.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="80.0" y1="75.0" x2="90.5" y2="107.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="90.5" y1="107.4" x2="80.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="80.0" y1="75.0" x2="52.5" y2="95.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="52.5" y1="95.0" x2="80.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="80.0" y1="75.0" x2="52.5" y2="55.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="52.5" y1="55.0" x2="80.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="80.0" y1="75.0" x2="90.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="90.5" y1="42.6" x2="80.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="80.0" y1="75.0" x2="114.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.0" y1="75.0" x2="90.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="90.5" y1="42.6" x2="52.5" y2="55.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="52.5" y1="55.0" x2="52.5" y2="95.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="52.5" y1="95.0" x2="90.5" y2="107.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="90.5" y1="107.4" x2="114.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.9" y1="68.7" x2="273.8" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="273.8" y1="66.6" x2="233.9" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.9" y1="68.7" x2="255.6" y2="102.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="255.6" y1="102.3" x2="233.9" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.9" y1="68.7" x2="215.7" y2="104.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.7" y1="104.4" x2="233.9" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.9" y1="68.7" x2="193.9" y2="70.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.9" y1="70.8" x2="233.9" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.9" y1="68.7" x2="212.1" y2="35.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.1" y1="35.2" x2="233.9" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.9" y1="68.7" x2="252.0" y2="33.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="252.0" y1="33.1" x2="233.9" y2="68.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.9" y1="68.7" x2="273.8" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="273.8" y1="66.6" x2="252.0" y2="33.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="252.0" y1="33.1" x2="212.1" y2="35.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.1" y1="35.2" x2="193.9" y2="70.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.9" y1="70.8" x2="215.7" y2="104.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="215.7" y1="104.4" x2="255.6" y2="102.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="255.6" y1="102.3" x2="273.8" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="393.8" y1="66.6" x2="439.9" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="439.9" y1="66.6" x2="393.8" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="393.8" y1="66.6" x2="422.5" y2="102.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="422.5" y1="102.7" x2="393.8" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="393.8" y1="66.6" x2="383.5" y2="111.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="383.5" y1="111.6" x2="393.8" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="393.8" y1="66.6" x2="352.3" y2="86.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="352.3" y1="86.6" x2="393.8" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="393.8" y1="66.6" x2="352.3" y2="46.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="352.3" y1="46.6" x2="393.8" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="393.8" y1="66.6" x2="383.5" y2="21.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="383.5" y1="21.7" x2="393.8" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="393.8" y1="66.6" x2="422.5" y2="30.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="422.5" y1="30.6" x2="393.8" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="393.8" y1="66.6" x2="439.9" y2="66.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="439.9" y1="66.6" x2="422.5" y2="30.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="422.5" y1="30.6" x2="383.5" y2="21.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="383.5" y1="21.7" x2="352.3" y2="46.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="352.3" y1="46.6" x2="352.3" y2="86.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="352.3" y1="86.6" x2="383.5" y2="111.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="383.5" y1="111.6" x2="422.5" y2="102.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="422.5" y1="102.7" x2="439.9" y2="66.6"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-82.7,558.9,81.8) translate(558.9, 81.8)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
def draw_pie(sides, length):
    angle = 360/sides
    # Distance from center to vertex
    radius = length/(2*math.sin(math.pi/sides))

    # Draw pie lines from center to vertices
    for _ in range(sides):
        forward(radius)
        left(180)
        forward(radius)
        left(180-angle)

    # Draw the polygon around the pie
    forward(radius) # move to first vertex
    # Orient correctly to draw polygon
    left(180-((180*(sides-2))/(2*sides)))
    polygon_side = 2*radius*math.sin(math.pi/sides)
    for _ in range(sides):
        forward(polygon_side)
        left(angle)

# %%
turtle = make_turtle(width=500, delay=0.02)
jump(-150)

size = 40
draw_pie(5, size)
right(125)
jump(3*size)
draw_pie(6, size)
right(125)
jump(3*size)
draw_pie(7, size)
# Out:
# <svg width="500" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="100.0" y1="75.0" x2="134.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.0" y1="75.0" x2="100.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.0" y1="75.0" x2="110.5" y2="107.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.5" y1="107.4" x2="100.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.0" y1="75.0" x2="72.5" y2="95.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="72.5" y1="95.0" x2="100.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.0" y1="75.0" x2="72.5" y2="55.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="72.5" y1="55.0" x2="100.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.0" y1="75.0" x2="110.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.5" y1="42.6" x2="100.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.0" y1="75.0" x2="134.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.0" y1="75.0" x2="110.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.5" y1="42.6" x2="72.5" y2="55.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="72.5" y1="55.0" x2="72.5" y2="95.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="72.5" y1="95.0" x2="110.5" y2="107.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.5" y1="107.4" x2="134.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.0" y1="72.9" x2="294.0" y2="72.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="294.0" y1="72.2" x2="254.0" y2="72.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.0" y1="72.9" x2="274.6" y2="107.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="274.6" y1="107.2" x2="254.0" y2="72.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.0" y1="72.9" x2="234.6" y2="107.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="234.6" y1="107.9" x2="254.0" y2="72.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.0" y1="72.9" x2="214.0" y2="73.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.0" y1="73.6" x2="254.0" y2="72.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.0" y1="72.9" x2="233.4" y2="38.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.4" y1="38.6" x2="254.0" y2="72.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.0" y1="72.9" x2="273.4" y2="37.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="273.4" y1="37.9" x2="254.0" y2="72.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="254.0" y1="72.9" x2="294.0" y2="72.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="294.0" y1="72.2" x2="273.4" y2="37.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="273.4" y1="37.9" x2="233.4" y2="38.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.4" y1="38.6" x2="214.0" y2="73.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.0" y1="73.6" x2="234.6" y2="107.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="234.6" y1="107.9" x2="274.6" y2="107.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="274.6" y1="107.2" x2="294.0" y2="72.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="413.7" y1="80.6" x2="459.7" y2="83.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="459.7" y1="83.8" x2="413.7" y2="80.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="413.7" y1="80.6" x2="439.9" y2="118.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="439.9" y1="118.5" x2="413.7" y2="80.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="413.7" y1="80.6" x2="400.3" y2="124.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="400.3" y1="124.7" x2="413.7" y2="80.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="413.7" y1="80.6" x2="370.9" y2="97.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="370.9" y1="97.6" x2="413.7" y2="80.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="413.7" y1="80.6" x2="373.7" y2="57.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="373.7" y1="57.7" x2="413.7" y2="80.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="413.7" y1="80.6" x2="406.6" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="406.6" y1="35.0" x2="413.7" y2="80.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="413.7" y1="80.6" x2="444.9" y2="46.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="444.9" y1="46.6" x2="413.7" y2="80.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="413.7" y1="80.6" x2="459.7" y2="83.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="459.7" y1="83.8" x2="444.9" y2="46.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="444.9" y1="46.6" x2="406.6" y2="35.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="406.6" y1="35.0" x2="373.7" y2="57.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="373.7" y1="57.7" x2="370.9" y2="97.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="370.9" y1="97.6" x2="400.3" y2="124.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="400.3" y1="124.7" x2="439.9" y2="118.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="439.9" y1="118.5" x2="459.7" y2="83.8"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(158.3,459.7,83.8) translate(459.7, 83.8)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ## Exercise 5
#
# Write an appropriately general set of functions that can draw flowers like this.
#
# ![](https://github.com/AllenDowney/ThinkPython/raw/v3/jupyturtle_flower.png)
#
# Hint: Use `arc` to write a function called `petal` that draws one flower petal.

# %%
"""Exercise 5 Solution"""
from jupyturtle import make_turtle, forward, left, right
import math

def polyline(n, length, angle):
    for _ in range(n):
        forward(length)
        left(angle)

def arc(radius, angle):
    arc_length = 2 * math.pi * radius * angle / 360
    n = 30
    length = arc_length / n
    step_angle = angle / n
    polyline(n, length, step_angle)

def petal(radius, angle):
    for _ in range(2):
        arc(radius, angle)
        left(180 - angle)

def flower(radius, angle, petals):
    for _ in range(petals):
        petal(radius, angle)
        left(360 / petals)

# %%
"""Exercise 5 Test"""
make_turtle(width=500, delay=0.001)
jump(-150)
flower(60, 60, 7)
jump(150)
flower(60, 60, 9)
# Out:
# <svg width="500" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="100.0" y1="75.0" x2="102.1" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.1" y1="75.0" x2="104.2" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.2" y1="74.9" x2="106.3" y2="74.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="106.3" y1="74.8" x2="108.4" y2="74.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="108.4" y1="74.6" x2="110.4" y2="74.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.4" y1="74.3" x2="112.5" y2="73.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.5" y1="73.9" x2="114.5" y2="73.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="114.5" y1="73.5" x2="116.6" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.6" y1="73.0" x2="118.6" y2="72.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="118.6" y1="72.4" x2="120.6" y2="71.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.6" y1="71.7" x2="122.6" y2="71.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.6" y1="71.0" x2="124.5" y2="70.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="124.5" y1="70.2" x2="126.4" y2="69.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.4" y1="69.4" x2="128.3" y2="68.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.3" y1="68.5" x2="130.1" y2="67.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="130.1" y1="67.5" x2="132.0" y2="66.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="132.0" y1="66.4" x2="133.7" y2="65.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.7" y1="65.3" x2="135.5" y2="64.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.5" y1="64.2" x2="137.2" y2="62.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.2" y1="62.9" x2="138.8" y2="61.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.8" y1="61.6" x2="140.4" y2="60.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.4" y1="60.3" x2="142.0" y2="58.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.0" y1="58.9" x2="143.5" y2="57.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.5" y1="57.4" x2="144.9" y2="55.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.9" y1="55.9" x2="146.3" y2="54.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.3" y1="54.4" x2="147.7" y2="52.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="147.7" y1="52.8" x2="149.0" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="149.0" y1="51.1" x2="150.2" y2="49.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.2" y1="49.4" x2="151.4" y2="47.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="151.4" y1="47.7" x2="152.5" y2="45.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.5" y1="45.9" x2="150.4" y2="45.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.4" y1="45.9" x2="148.3" y2="46.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.3" y1="46.0" x2="146.2" y2="46.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.2" y1="46.1" x2="144.1" y2="46.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.1" y1="46.3" x2="142.0" y2="46.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.0" y1="46.6" x2="140.0" y2="47.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="47.0" x2="137.9" y2="47.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="137.9" y1="47.4" x2="135.9" y2="47.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="135.9" y1="47.9" x2="133.9" y2="48.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.9" y1="48.5" x2="131.9" y2="49.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="131.9" y1="49.2" x2="129.9" y2="49.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="129.9" y1="49.9" x2="128.0" y2="50.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.0" y1="50.7" x2="126.1" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.1" y1="51.5" x2="124.2" y2="52.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="124.2" y1="52.4" x2="122.3" y2="53.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.3" y1="53.4" x2="120.5" y2="54.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="120.5" y1="54.5" x2="118.8" y2="55.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="118.8" y1="55.6" x2="117.0" y2="56.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="117.0" y1="56.8" x2="115.3" y2="58.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="115.3" y1="58.0" x2="113.7" y2="59.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="113.7" y1="59.3" x2="112.1" y2="60.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.1" y1="60.6" x2="110.5" y2="62.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.5" y1="62.0" x2="109.0" y2="63.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="109.0" y1="63.5" x2="107.5" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="107.5" y1="65.0" x2="106.1" y2="66.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="106.1" y1="66.5" x2="104.8" y2="68.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.8" y1="68.1" x2="103.5" y2="69.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.5" y1="69.8" x2="102.3" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.3" y1="71.5" x2="101.1" y2="73.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="101.1" y1="73.2" x2="100.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="100.0" y1="75.0" x2="101.3" y2="73.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="101.3" y1="73.4" x2="102.6" y2="71.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="102.6" y1="71.7" x2="103.7" y2="70.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="103.7" y1="70.0" x2="104.9" y2="68.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.9" y1="68.2" x2="105.9" y2="66.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="105.9" y1="66.4" x2="106.9" y2="64.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="106.9" y1="64.5" x2="107.9" y2="62.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="107.9" y1="62.7" x2="108.7" y2="60.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="108.7" y1="60.8" x2="109.5" y2="58.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="109.5" y1="58.8" x2="110.3" y2="56.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.3" y1="56.9" x2="111.0" y2="54.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="111.0" y1="54.9" x2="111.5" y2="52.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="111.5" y1="52.9" x2="112.1" y2="50.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.1" y1="50.9" x2="112.5" y2="48.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.5" y1="48.8" x2="112.9" y2="46.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.9" y1="46.8" x2="113.2" y2="44.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="113.2" y1="44.7" x2="113.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="113.5" y1="42.6" x2="113.6" y2="40.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="113.6" y1="40.5" x2="113.7" y2="38.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="113.7" y1="38.4" x2="113.7" y2="36.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="113.7" y1="36.3" x2="113.7" y2="34.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="113.7" y1="34.2" x2="113.6" y2="32.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="113.6" y1="32.1" x2="113.4" y2="30.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="113.4" y1="30.1" x2="113.1" y2="28.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="113.1" y1="28.0" x2="112.8" y2="25.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.8" y1="25.9" x2="112.3" y2="23.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="112.3" y1="23.9" x2="111.9" y2="21.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="111.9" y1="21.8" x2="111.3" y2="19.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="111.3" y1="19.8" x2="110.7" y2="17.8"
#     stroke="#663399" stroke-width

# %%
from jupyturtle import render

make_turtle(width=500, delay=0.001, auto_render=False)

jump(-60)
n = 7
radius = 60
angle = 60
flower(radius, angle, n)

jump(120)
n = 9
radius = 40
angle = 85
flower(radius, angle, n)

render()
# Out:
# Warning: delay is ignored when auto_render=False
# <svg width="500" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="190.0" y1="75.0" x2="192.1" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.1" y1="75.0" x2="194.2" y2="74.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.2" y1="74.9" x2="196.3" y2="74.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="196.3" y1="74.8" x2="198.4" y2="74.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.4" y1="74.6" x2="200.4" y2="74.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.4" y1="74.3" x2="202.5" y2="73.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.5" y1="73.9" x2="204.5" y2="73.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="204.5" y1="73.5" x2="206.6" y2="73.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="206.6" y1="73.0" x2="208.6" y2="72.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.6" y1="72.4" x2="210.6" y2="71.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.6" y1="71.7" x2="212.6" y2="71.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.6" y1="71.0" x2="214.5" y2="70.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.5" y1="70.2" x2="216.4" y2="69.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.4" y1="69.4" x2="218.3" y2="68.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="218.3" y1="68.5" x2="220.1" y2="67.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="220.1" y1="67.5" x2="222.0" y2="66.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="222.0" y1="66.4" x2="223.7" y2="65.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="223.7" y1="65.3" x2="225.5" y2="64.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="225.5" y1="64.2" x2="227.2" y2="62.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="227.2" y1="62.9" x2="228.8" y2="61.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="228.8" y1="61.6" x2="230.4" y2="60.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.4" y1="60.3" x2="232.0" y2="58.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="232.0" y1="58.9" x2="233.5" y2="57.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="233.5" y1="57.4" x2="234.9" y2="55.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="234.9" y1="55.9" x2="236.3" y2="54.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="236.3" y1="54.4" x2="237.7" y2="52.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="237.7" y1="52.8" x2="239.0" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="239.0" y1="51.1" x2="240.2" y2="49.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="240.2" y1="49.4" x2="241.4" y2="47.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="241.4" y1="47.7" x2="242.5" y2="45.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="242.5" y1="45.9" x2="240.4" y2="45.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="240.4" y1="45.9" x2="238.3" y2="46.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="238.3" y1="46.0" x2="236.2" y2="46.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="236.2" y1="46.1" x2="234.1" y2="46.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="234.1" y1="46.3" x2="232.0" y2="46.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="232.0" y1="46.6" x2="230.0" y2="47.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="230.0" y1="47.0" x2="227.9" y2="47.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="227.9" y1="47.4" x2="225.9" y2="47.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="225.9" y1="47.9" x2="223.9" y2="48.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="223.9" y1="48.5" x2="221.9" y2="49.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="221.9" y1="49.2" x2="219.9" y2="49.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="219.9" y1="49.9" x2="218.0" y2="50.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="218.0" y1="50.7" x2="216.1" y2="51.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.1" y1="51.5" x2="214.2" y2="52.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.2" y1="52.4" x2="212.3" y2="53.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.3" y1="53.4" x2="210.5" y2="54.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.5" y1="54.5" x2="208.8" y2="55.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.8" y1="55.6" x2="207.0" y2="56.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.0" y1="56.8" x2="205.3" y2="58.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.3" y1="58.0" x2="203.7" y2="59.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.7" y1="59.3" x2="202.1" y2="60.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.1" y1="60.6" x2="200.5" y2="62.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.5" y1="62.0" x2="199.0" y2="63.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.0" y1="63.5" x2="197.5" y2="65.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.5" y1="65.0" x2="196.1" y2="66.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="196.1" y1="66.5" x2="194.8" y2="68.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.8" y1="68.1" x2="193.5" y2="69.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.5" y1="69.8" x2="192.3" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.3" y1="71.5" x2="191.1" y2="73.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="191.1" y1="73.2" x2="190.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.0" y1="75.0" x2="191.3" y2="73.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="191.3" y1="73.4" x2="192.6" y2="71.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.6" y1="71.7" x2="193.7" y2="70.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.7" y1="70.0" x2="194.9" y2="68.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.9" y1="68.2" x2="195.9" y2="66.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="195.9" y1="66.4" x2="196.9" y2="64.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="196.9" y1="64.5" x2="197.9" y2="62.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.9" y1="62.7" x2="198.7" y2="60.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.7" y1="60.8" x2="199.5" y2="58.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="199.5" y1="58.8" x2="200.3" y2="56.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.3" y1="56.9" x2="201.0" y2="54.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.0" y1="54.9" x2="201.5" y2="52.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.5" y1="52.9" x2="202.1" y2="50.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.1" y1="50.9" x2="202.5" y2="48.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.5" y1="48.8" x2="202.9" y2="46.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.9" y1="46.8" x2="203.2" y2="44.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.2" y1="44.7" x2="203.5" y2="42.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.5" y1="42.6" x2="203.6" y2="40.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.6" y1="40.5" x2="203.7" y2="38.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.7" y1="38.4" x2="203.7" y2="36.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.7" y1="36.3" x2="203.7" y2="34.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.7" y1="34.2" x2="203.6" y2="32.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.6" y1="32.1" x2="203.4" y2="30.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.4" y1="30.1" x2="203.1" y2="28.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.1" y1="28.0" x2="202.8" y2="25.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.8" y1="25.9" x2="202.3" y2="23.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.3" y1="23.9" x2="201.9" y2="21.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.9" y1="21.8" x2="201.3" y2="19.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.3" y1="19.8" x2="200.7" y2="17.8"
#     stroke="#663399" stroke-width

# %%
from jupyturtle import make_turtle, forward, left
import math

def polygon(n, length):
    angle = 360 / n
    for i in range(n):
        forward(length)
        left(angle)
        
def circle(radius):
    circumference = 2 * math.pi * radius
    n = 30
    length = circumference / n
    polygon(n, length)

def square_spiral(initial_length, increment, turns):
    """
    Dibuja una espiral cuadrada aumentando la longitud en cada paso.
    
    Args:
        initial_length: longitud inicial del segmento
        increment: cuánto aumentar la longitud en cada paso
        turns: número de vueltas/iteraciones
    """
    length = initial_length
    angle = 90  # Puedes cambiar este ángulo para diferentes efectos
    
    for i in range(turns):
        forward(length)
        left(angle)
        length += increment

# Ejemplo de uso:
make_turtle(height=300, width=400, delay=0)
square_spiral(5, 3, 70)
# Out:
# <svg width="400" height="300">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="200" y1="150" x2="205.0" y2="150.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.0" y1="150.0" x2="205.0" y2="142.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.0" y1="142.0" x2="194.0" y2="142.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="142.0" x2="194.0" y2="156.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="194.0" y1="156.0" x2="211.0" y2="156.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.0" y1="156.0" x2="211.0" y2="136.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.0" y1="136.0" x2="188.0" y2="136.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.0" y1="136.0" x2="188.0" y2="162.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.0" y1="162.0" x2="217.0" y2="162.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.0" y1="162.0" x2="217.0" y2="130.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.0" y1="130.0" x2="182.0" y2="130.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.0" y1="130.0" x2="182.0" y2="168.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.0" y1="168.0" x2="223.0" y2="168.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="223.0" y1="168.0" x2="223.0" y2="124.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="223.0" y1="124.0" x2="176.0" y2="124.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.0" y1="124.0" x2="176.0" y2="174.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="176.0" y1="174.0" x2="229.0" y2="174.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="229.0" y1="174.0" x2="229.0" y2="118.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="229.0" y1="118.0" x2="170.0" y2="118.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="118.0" x2="170.0" y2="180.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="170.0" y1="180.0" x2="235.0" y2="180.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="235.0" y1="180.0" x2="235.0" y2="112.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="235.0" y1="112.0" x2="164.0" y2="112.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.0" y1="112.0" x2="164.0" y2="186.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="164.0" y1="186.0" x2="241.0" y2="186.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="241.0" y1="186.0" x2="241.0" y2="106.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="241.0" y1="106.0" x2="158.0" y2="106.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.0" y1="106.0" x2="158.0" y2="192.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.0" y1="192.0" x2="247.0" y2="192.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="247.0" y1="192.0" x2="247.0" y2="100.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="247.0" y1="100.0" x2="152.0" y2="100.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.0" y1="100.0" x2="152.0" y2="198.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.0" y1="198.0" x2="253.0" y2="198.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="253.0" y1="198.0" x2="253.0" y2="94.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="253.0" y1="94.0" x2="146.0" y2="94.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.0" y1="94.0" x2="146.0" y2="204.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.0" y1="204.0" x2="259.0" y2="204.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="259.0" y1="204.0" x2="259.0" y2="88.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="259.0" y1="88.0" x2="140.0" y2="88.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="88.0" x2="140.0" y2="210.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="210.0" x2="265.0" y2="210.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="265.0" y1="210.0" x2="265.0" y2="82.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="265.0" y1="82.0" x2="134.0" y2="82.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.0" y1="82.0" x2="134.0" y2="216.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="134.0" y1="216.0" x2="271.0" y2="216.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="271.0" y1="216.0" x2="271.0" y2="76.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="271.0" y1="76.0" x2="128.0" y2="76.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.0" y1="76.0" x2="128.0" y2="222.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="128.0" y1="222.0" x2="277.0" y2="222.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="277.0" y1="222.0" x2="277.0" y2="70.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="277.0" y1="70.0" x2="122.0" y2="70.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.0" y1="70.0" x2="122.0" y2="228.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="122.0" y1="228.0" x2="283.0" y2="228.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="283.0" y1="228.0" x2="283.0" y2="64.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="283.0" y1="64.0" x2="116.0" y2="64.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.0" y1="64.0" x2="116.0" y2="234.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.0" y1="234.0" x2="289.0" y2="234.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="289.0" y1="234.0" x2="289.0" y2="58.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="289.0" y1="58.0" x2="110.0" y2="58.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="58.0" x2="110.0" y2="240.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="110.0" y1="240.0" x2="295.0" y2="240.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="295.0" y1="240.0" x2="295.0" y2="52.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="295.0" y1="52.0" x2="104.0" y2="52.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.0" y1="52.0" x2="104.0" y2="246.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="104.0" y1="246.0" x2="301.0" y2="246.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="301.0" y1="246.0" x2="301.0" y2="46.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="301.0" y1="46.0" x2="98.0" y2="46.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.0" y1="46.0" x2="98.0" y2="252.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="98.0" y1="252.0" x2="307.0" y2="252.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="307.0" y1="252.0" x2="307.0" y2="40.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(90.0,307.0,40.0) translate(307.0, 40.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
def archimedes_spiral(turns, spacing):
    """
    Dibuja una espiral de Arquímedes (espiral suave).
    
    Args:
        turns: número de vueltas completas
        spacing: espacio entre cada vuelta
    """
    angle = 1  # Ángulo pequeño para movimiento suave
    total_steps = turns * 360
    
    for i in range(total_steps):
        # La distancia aumenta proporcionalmente al ángulo
        distance = spacing * i / 360
        forward(distance)
        left(angle)

# Ejemplo de uso:
make_turtle(height=400, width=400, auto_render=False)
archimedes_spiral(5, 0.5)
render()
# Out:
# <svg width="400" height="400">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="200" y1="200" x2="200.0" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="200.0" x2="200.0" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="200.0" x2="200.0" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="200.0" x2="200.0" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="200.0" x2="200.0" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="200.0" x2="200.0" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="200.0" x2="200.0" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="200.0" x2="200.0" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="200.0" x2="200.0" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.0" y1="200.0" x2="200.1" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.1" y1="200.0" x2="200.1" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.1" y1="200.0" x2="200.1" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.1" y1="200.0" x2="200.1" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.1" y1="200.0" x2="200.1" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.1" y1="200.0" x2="200.1" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.1" y1="200.0" x2="200.2" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.2" y1="200.0" x2="200.2" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.2" y1="200.0" x2="200.2" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.2" y1="200.0" x2="200.2" y2="199.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.2" y1="199.9" x2="200.3" y2="199.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.3" y1="199.9" x2="200.3" y2="199.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.3" y1="199.9" x2="200.3" y2="199.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.3" y1="199.9" x2="200.3" y2="199.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.3" y1="199.9" x2="200.4" y2="199.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.4" y1="199.9" x2="200.4" y2="199.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.4" y1="199.9" x2="200.4" y2="199.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.4" y1="199.9" x2="200.5" y2="199.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.5" y1="199.9" x2="200.5" y2="199.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.5" y1="199.8" x2="200.5" y2="199.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.5" y1="199.8" x2="200.6" y2="199.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.6" y1="199.8" x2="200.6" y2="199.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.6" y1="199.8" x2="200.6" y2="199.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.6" y1="199.8" x2="200.7" y2="199.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.7" y1="199.7" x2="200.7" y2="199.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.7" y1="199.7" x2="200.8" y2="199.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.8" y1="199.7" x2="200.8" y2="199.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.8" y1="199.7" x2="200.8" y2="199.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.8" y1="199.6" x2="200.9" y2="199.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.9" y1="199.6" x2="200.9" y2="199.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.9" y1="199.6" x2="201.0" y2="199.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.0" y1="199.5" x2="201.0" y2="199.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.0" y1="199.5" x2="201.0" y2="199.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.0" y1="199.5" x2="201.1" y2="199.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.1" y1="199.4" x2="201.1" y2="199.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.1" y1="199.4" x2="201.2" y2="199.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.2" y1="199.3" x2="201.2" y2="199.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.2" y1="199.3" x2="201.3" y2="199.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.3" y1="199.2" x2="201.3" y2="199.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.3" y1="199.2" x2="201.4" y2="199.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.4" y1="199.1" x2="201.4" y2="199.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.4" y1="199.1" x2="201.4" y2="199.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.4" y1="199.0" x2="201.5" y2="199.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.5" y1="199.0" x2="201.5" y2="198.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.5" y1="198.9" x2="201.6" y2="198.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.6" y1="198.9" x2="201.6" y2="198.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.6" y1="198.8" x2="201.7" y2="198.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.7" y1="198.7" x2="201.7" y2="198.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.7" y1="198.7" x2="201.7" y2="198.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.7" y1="198.6" x2="201.8" y2="198.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.8" y1="198.5" x2="201.8" y2="198.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.8" y1="198.5" x2="201.9" y2="198.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.9" y1="198.4" x2="201.9" y2="198.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.9" y1="198.3" x2="202.0" y2="198.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.0" y1="198.3" x2="202.0" y2="198.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.0" y1="198.2" x2="202.0" y2="198.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.0" y1="198.1" x2="202.1" y2="198.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.1" y1="198.0" x2="202.1" y2="197.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.1" y1="197.9" x2="202.1" y2="197.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.1" y1="197.8" x2="202.2" y2="197.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.2" y1="197.8" x2="202.2" y2="197.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.2" y1="197.7" x2="202.3" y2="197.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.3" y1="197.6" x2="202.3" y2="197.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.3" y1="197.5" x2="202.3" y2="197.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.3" y1="197.4" x2="202.3" y2="197.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.3" y1="197.3" x2="202.4" y2="197.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.4" y1="197.2" x2="202.4" y2="197.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.4" y1="197.1" x2="202.4" y2="197.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.4" y1="197.0" x2="202.4" y2="196.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.4" y1="196.9" x2="202.5" y2="196.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.5" y1="196.8" x2="202.5" y2="196.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.5" y1="196.7" x2="202.5" y2="196.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.5" y1="196.6" x2="202.5" y2="196.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.5" y1="196.4" x2="202.5" y2="196.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.5" y1="196.3" x2="202.6" y2="196.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.6" y1="196.2" x2="202.6" y2="196.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.6" y1="196.1" x2="202.6" y2="196.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.6" y1="196.0" x2="202.6" y2="195.9"
#     stroke="#663399" stroke-width="2" />

# %%
def logarithmic_spiral(growth_factor, turns, step_angle=5):
    """
    Dibuja una espiral logarítmica.
    
    Args:
        growth_factor: factor de crecimiento (ej: 1.1)
        turns: número de vueltas
        step_angle: ángulo de cada paso
    """
    length = 1
    total_steps = int(turns * 360 / step_angle)
    
    for i in range(total_steps):
        forward(length)
        left(step_angle)
        length *= growth_factor ** (step_angle / 360)

# Ejemplo de uso:
make_turtle(height=400, width=400, delay=0)
logarithmic_spiral(1.7, 5)
# Out:
# <svg width="400" height="400">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="200" y1="200" x2="201.0" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.0" y1="200.0" x2="202.0" y2="199.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.0" y1="199.9" x2="203.0" y2="199.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.0" y1="199.7" x2="204.0" y2="199.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="204.0" y1="199.5" x2="205.0" y2="199.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.0" y1="199.1" x2="205.9" y2="198.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.9" y1="198.7" x2="206.8" y2="198.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="206.8" y1="198.2" x2="207.7" y2="197.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.7" y1="197.6" x2="208.5" y2="196.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.5" y1="196.9" x2="209.2" y2="196.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="209.2" y1="196.1" x2="209.9" y2="195.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="209.9" y1="195.3" x2="210.5" y2="194.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.5" y1="194.4" x2="211.1" y2="193.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.1" y1="193.5" x2="211.6" y2="192.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.6" y1="192.5" x2="211.9" y2="191.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.9" y1="191.4" x2="212.2" y2="190.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.2" y1="190.3" x2="212.4" y2="189.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.4" y1="189.2" x2="212.5" y2="188.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.5" y1="188.1" x2="212.5" y2="187.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.5" y1="187.0" x2="212.4" y2="185.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.4" y1="185.8" x2="212.2" y2="184.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="212.2" y1="184.7" x2="211.9" y2="183.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.9" y1="183.5" x2="211.5" y2="182.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.5" y1="182.4" x2="211.0" y2="181.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.0" y1="181.4" x2="210.4" y2="180.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.4" y1="180.3" x2="209.7" y2="179.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="209.7" y1="179.3" x2="209.0" y2="178.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="209.0" y1="178.4" x2="208.1" y2="177.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.1" y1="177.6" x2="207.1" y2="176.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.1" y1="176.8" x2="206.1" y2="176.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="206.1" y1="176.1" x2="205.1" y2="175.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.1" y1="175.4" x2="203.9" y2="174.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.9" y1="174.9" x2="202.7" y2="174.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.7" y1="174.5" x2="201.5" y2="174.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="201.5" y1="174.1" x2="200.2" y2="173.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.2" y1="173.9" x2="198.9" y2="173.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.9" y1="173.8" x2="197.6" y2="173.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.6" y1="173.8" x2="196.3" y2="173.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="196.3" y1="173.9" x2="195.0" y2="174.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="195.0" y1="174.1" x2="193.7" y2="174.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.7" y1="174.5" x2="192.5" y2="175.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.5" y1="175.0" x2="191.2" y2="175.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="191.2" y1="175.5" x2="190.1" y2="176.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.1" y1="176.2" x2="188.9" y2="177.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.9" y1="177.0" x2="187.9" y2="177.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.9" y1="177.9" x2="186.9" y2="178.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.9" y1="178.9" x2="186.0" y2="179.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.0" y1="179.9" x2="185.2" y2="181.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.2" y1="181.1" x2="184.5" y2="182.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.5" y1="182.3" x2="183.9" y2="183.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.9" y1="183.6" x2="183.4" y2="185.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.4" y1="185.0" x2="183.0" y2="186.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.0" y1="186.4" x2="182.7" y2="187.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.7" y1="187.8" x2="182.6" y2="189.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.6" y1="189.3" x2="182.6" y2="190.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.6" y1="190.8" x2="182.7" y2="192.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="182.7" y1="192.3" x2="183.0" y2="193.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.0" y1="193.8" x2="183.4" y2="195.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.4" y1="195.3" x2="183.9" y2="196.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.9" y1="196.7" x2="184.6" y2="198.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="184.6" y1="198.1" x2="185.4" y2="199.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="185.4" y1="199.4" x2="186.3" y2="200.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="186.3" y1="200.7" x2="187.3" y2="201.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="187.3" y1="201.9" x2="188.4" y2="203.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="188.4" y1="203.1" x2="189.6" y2="204.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="189.6" y1="204.1" x2="190.9" y2="205.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="190.9" y1="205.0" x2="192.4" y2="205.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="192.4" y1="205.8" x2="193.8" y2="206.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="193.8" y1="206.5" x2="195.4" y2="207.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="195.4" y1="207.1" x2="197.0" y2="207.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="197.0" y1="207.5" x2="198.6" y2="207.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="198.6" y1="207.8" x2="200.3" y2="208.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="200.3" y1="208.0" x2="202.0" y2="208.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="202.0" y1="208.0" x2="203.7" y2="207.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="203.7" y1="207.8" x2="205.4" y2="207.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="205.4" y1="207.5" x2="207.1" y2="207.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="207.1" y1="207.1" x2="208.8" y2="206.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="208.8" y1="206.5" x2="210.4" y2="205.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="210.4" y1="205.7" x2="211.9" y2="204.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="211.9" y1="204.8" x2="213.4" y2="203.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="213.4" y1="203.8" x2="214.7" y2="202.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="214.7" y1="202.6" x2="216.0" y2="201.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="216.0" y1="201.4" x2="217.2" y2="200.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="217.2" y1="200.0" x2="218.3" y2="198.4"
#     stroke="#663399" stroke-width="2" />
# <line x1="218.3" y1="198.4" x2="219.2" y2="196.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="219.2" y1="196.8" x2="220.0" y2="195.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="220.0" y1="195.1" x2="220.6" y2="193.4"
#     stroke="#663399" stroke-width="2" />

# %% [markdown]
# # Chapter 5: Conditionals and Recursion
# ## Exercise 1
# Use integer division and the modulus operator to compute the number of days since January 1, 1970 and the current time of day in hours, minutes, and seconds.

# %%
"""Exercise 1: Answer"""
from time import time

now = time()
print(f"Seconds since Unix epoch(january 1, 1970): {now}")

# Calculate the number of seconds in a day
seconds_in_day = 24 * 60 * 60

# Calculate the number of days since the epoch using integer division
days_since_epoch = int(now // seconds_in_day)
print(f"Days since epoch: {days_since_epoch}")

# Calculate the remaining seconds in the current day using the modulus operator
remaining_seconds = now % seconds_in_day

# Calculate hours from the remaining seconds using integer division
hours = int(remaining_seconds // (60 * 60))

# Calculate the remaining seconds after accounting for hours using the modulus operator
remaining_seconds %= (60 * 60)

# Calculate minutes from the remaining seconds using integer division
minutes = int(remaining_seconds // 60)

# Calculate the remaining seconds after accounting for minutes using the modulus operator
seconds = int(remaining_seconds % 60)

print(f"Current time: {hours:02d}:{minutes:02d}:{seconds:02d}")

# %% [markdown]
# ## Exercise 2
# Write a function named is_triangle that takes three integers as arguments, and that prints either "Yes" or "No", depending on whether you can or cannot form a triangle from sticks with the given lengths. Hint: Use a chained conditional.

# %%
"""Exercise 2: Answer"""
def is_triangle(a, b, c):
    """
    Checks if three lengths can form a triangle and prints 'Yes' or 'No'.

    Args:
        a: The length of the first side.
        b: The length of the second side.
        c: The length of the third side.
    """
    if a > b + c or b > a + c or c > a + b:
        print("No")
    else:
        print("Yes")
# Examples
print("Can a triangle with lengths 4, 5 and 6 be created?")
triangle1 = is_triangle(4, 5, 6) # should be Yes
print("Can a triangle with lengths 1, 2 and 3 be created?")
is_triangle(1, 2, 3)   # should be Yes
print("Can a triangle with lengths 6, 2 and 3 be created?")
is_triangle(6, 2, 3)   # should be No
print("Can a triangle with lengths 1, 1 and 12 be created?")
is_triangle(1, 1, 12)   # should be No

# %% [markdown]
# ## Exercise 3
# What is the output of the program written? Draw a stack diagram that shows the state of the program when it prints the result.

# %%
"""Exercise 3: Answer"""
def recurse(n, s):
    if n == 0:
        print(s)
    else:
        recurse(n-1, n+s)

recurse(3, 0)
print()
print()
# Stack program
from diagram import make_frame, Stack
from diagram import diagram, adjust

# Build the stack frames (from initial call to base case)
frames = []
# The call sequence is recurse(3, 0) -> recurse(2, 3) -> recurse(1, 5) -> recurse(0, 6)
call_args = [
    {'n': 3, 's': 0},
    {'n': 2, 's': 3},
    {'n': 1, 's': 5},
    {'n': 0, 's': 6}  # Base case, prints 6
]

for args in call_args:
    frame = make_frame(args, name='recurse', dx=1.3, loc='left')  # dx for horizontal offset (optional)
    frames.append(frame)

stack = Stack(frames, dy=-0.5)  # Negative dy stacks downward

width, height, x, y = [3.5, 2, 1, 1.8]
ax = diagram(width, height)
bbox = stack.draw(ax, x, y)
# adjust(x, y, bbox)

# %% [markdown]
# ## Exercise 4
# Read the function and see if you can figure out what it does. Then run it and see if you got it right. Adjust the values of length, angle and factor and see what effect they have on the result. If you are not sure you understand how it works, try asking a virtual assistant.

# %%
"""Exercise 4: Answer"""
# Example function code
from jupyturtle import forward, left, right, back, make_turtle

def draw(length):
    angle = 50
    factor = 0.6

    if length > 5:
        forward(length)
        left(angle)
        draw(factor * length)
        right(2 * angle)
        draw(factor * length)
        left(angle)
        back(length)
"""Result"""
make_turtle(delay = 0.1)
draw(30)

# %% [markdown]
# ## Exercise 5
# Ask a virtual assistant "What is the Koch curve?"
#
#         To draw a Koch curve with length x, all you have to do is
#         Turn left 60 degrees.
#         Draw a Koch curve with length x/3.
#         Turn right 120 degrees.
#         Draw a Koch curve with length x/3.
#         Turn left 60 degrees.
#         Draw a Koch curve with length x/3.
#
#         The exception is if x is less than 5 -- in that case, you can just draw a straight line with length x.
#
#         Write a function called koch that takes x as an argument and draws a Koch curve with the given length.
#
#         Once you have koch working, you can use this loop to draw three Koch curves in the shape of a snowflake.

# %%
"""Exercise 5"""
from jupyturtle import forward, left, right, back, make_turtle
def koch(x):
  if x < 5:
    forward(x)
  else:
    koch(x/3)
    left(60)
    koch(x/3)
    right(120)
    koch(x/3)
    left(60)
    koch(x/3)
# Result 1
make_turtle(delay=0)
koch(120)
# Snowflake
make_turtle(delay=0, height=300)
for i in range(3):
    koch(120)
    right(120)

# %% [markdown]
# ## Exercise 6
# As an example, ask a VA for a program that draws a Sierpiński triangle. The code you get should be a good starting place, but you might have to do some debugging. If the first attempt doesn't work, you can tell the VA what happened and ask for help -- or you can debug it yourself.

# %%
"""Exercise 6: Answer"""
from jupyturtle import forward, left, right, make_turtle, penup, pendown
import math

def draw_sierpinski_alt(t, length, depth):
    """
    Draws a Sierpiński triangle using an alternative recursive method.

    Args:
        t: The turtle object.
        length: The side length of the current triangle.
        depth: The recursion depth.
    """
    if depth == 0:
        # Draw a filled triangle (optional, can just draw the outline)
        # For simplicity, let's draw the outline of the base case triangle
        for _ in range(3):
            t.forward(length)
            t.left(120)
    else:
        draw_sierpinski_alt(t, length / 2, depth - 1)
        t.forward(length / 2)
        draw_sierpinski_alt(t, length / 2, depth - 1)
        # Replace t.backward(length / 2) with turns and forward
        t.left(180)
        t.forward(length / 2)
        t.left(180)

        t.left(60)
        t.forward(length / 2)
        t.right(60)
        draw_sierpinski_alt(t, length / 2, depth - 1)
        t.left(60)
        # Replace t.backward(length / 2) with turns and forward
        t.left(180)
        t.forward(length / 2)
        t.left(180)

        t.right(60)


# Create a turtle instance
t = make_turtle(delay=0, height=400, width=400)

# Calculate starting position to center the triangle
initial_length = 300
triangle_height = initial_length * math.sqrt(3) / 2

# Move the turtle to the calculated starting position without drawing
t.penup() # Lift the pen
t.left(180)
t.forward(initial_length / 2)
t.left(90)
t.forward(triangle_height / 3) # Adjust this factor as needed for better vertical centering
t.right(90)
t.left(180) # Turn back to original orientation
t.pendown() # Put the pen down

# Draw the Sierpiński triangle
draw_sierpinski_alt(t, initial_length, 4) # Adjust length and depth as needed

# %%
from jupyturtle import make_turtle, penup, pendown
import math
# Create a new turtle instance each time to clear the previous drawing
t = make_turtle(delay=0.1)

# Calculate starting position to center the triangle
initial_length = 100  # Use the length used for drawing
triangle_height = initial_length * math.sqrt(3) / 2

# Move the turtle to the calculated starting position without drawing
t.penup() # Lift the pen
t.left(180)
t.forward(initial_length / 2)
t.left(90)
t.forward(triangle_height / 3) # Adjust this factor as needed for better vertical centering
t.right(90)
t.left(180) # Turn back to original orientation
t.pendown() # Put the pen down

draw_sierpinski_alt(t, initial_length, 3) # Adjust length and depth as needed

# %% [markdown]
# # Chapter 6: Return Values
# ## Exercises
#
# 1.   Use incremental development to write a function called hypot that returns the length of the hypotenuse of a right triangle given the lengths of the other two legs as arguments.
#
#   Note: There's a function in the math module called hypot that does the same thing, but you should not use it for this exercise!
#
#   Even if you can write the function correctly on the first try, start with a function that always returns 0 and practice making small changes, testing as you go. When you are done, the function should only return a value -- it should not display anything.
# 2.   Write a boolean function, is_between(x, y, z), that returns True if  x<y<z  or if  z<y<x , andFalse otherwise.
# 3.  The Ackermann function,  A(m,n) , is defined:
#
#   A(m,n)=⎧⎩⎨n+1A(m−1,1)A(m−1,A(m,n−1))if m=0if m>0 and n=0if m>0 and n>0.
#
#   Write a function named ackermann that evaluates the Ackermann function. What happens if you call ackermann(5, 5)?
# 4.  A number,  a , is a power of  b  if it is divisible by  b  and  a/b  is a power of  b . Write a function called is_power that takes parameters a and b and returns True if a is a power of b. Note: you will have to think about the base case.
# 5.  The greatest common divisor (GCD) of  a  and  b  is the largest number that divides both of them with no remainder.
#
#   One way to find the GCD of two numbers is based on the observation that if  r  is the remainder when  a  is divided by  b , then  gcd(a,b)=gcd(b,r) . As a base case, we can use  gcd(a,0)=a .
#
#   Write a function called gcd that takes parameters a and b and returns their greatest common divisor.

# %%
# Exercise 1
import math
def hypot(x, y):
  squared_x = x ** 2
  squared_y = y ** 2
  square_sum = squared_x + squared_y
  return math.sqrt(square_sum)

# test resul with 3 and 4
hypot(3, 4)

# %%
# Exercise 2
def is_between(x, y, z):
  if x < y < z or z < y < x:
    return True
  else:
    return False

# Tests
print(is_between(1, 2, 3))  # should be True
print(is_between(3, 2, 1))  # should be True
print(is_between(1, 3, 2))  # should be False
print(is_between(2, 3, 1))  # should be False

# %%
# Exercise 3
def ackermann(m, n):
  if m == 0:
    return n + 1
  elif m > 0 and n == 0:
    return ackermann(m - 1, 1)
  elif m > 0 and n > 0:
    return ackermann(m - 1, ackermann(m, n - 1))

# Tests
print(ackermann(3, 2))  # should be 29
print(ackermann(3, 3))  # should be 61
print(ackermann(3, 4))  # should be 125

# %%
# Exercise 4
def is_power(a, b):
    if a == 1:
        return True              # base case: any number to the power 0 is 1
    elif b == 1:
        return a == 1           # 1^k is always 1, so only True if a==1
    elif a % b != 0:
        return False            # not divisible means it's not a power
    else:
        return is_power(a // b, b)   # integer division for next recursion

# Tests
print(is_power(65536, 2))   # should be True
print(is_power(27, 3))  # should be True
print(is_power(24, 2))  # should be False
print(is_power(1, 17))   # should be True
print(is_power(8, 2))     # True, because 8 = 2^3
print(is_power(27, 3))    # True, because 27 = 3^3
print(is_power(24, 2))    # False, not a power of 2
print(is_power(1, 17))    # True, any number to the power 0 is 1

# %%
# Exercise 5
def gcd(a, b):
    r = a % b
    if r == 0:
        return b
    else:
        return gcd(b, r)

# Tests
print(gcd(12, 8))    # should be 4
print(gcd(13, 17))   # should be 1

# %%
from doctest import run_docstring_examples

def run_doctests(func):
    run_docstring_examples(func, globals(), name=func.__name__)

# %% [markdown]
# # Chapter 7: Iteration and Search
# ## Exercises
#
# 1.  Write a function named "uses_none" that takes a word and a string of forbidden letters, and returns True if the word does not use any of the forbidden letters.
# 2.  Write a function called uses_all that takes a word and a string of letters, and that returns True if the word contains all of the letters in the string at least once.
# 3.  The New York Times publishes a daily puzzle called "Spelling Bee" that challenges readers to spell as many words as possible using only seven letters, where one of the letters is required. The words must have at least four letters.
#
#   For example, on the day I wrote this, the letters were ACDLORT, with R as the required letter. So "color" is an acceptable word, but "told" is not, because it does not use R, and "rat" is not because it has only three letters. Letters can be repeated, so "ratatat" is acceptable.
#
#   Write a function called check_word that checks whether a given word is acceptable. It should take as parameters the word to check, a string of seven available letters, and a string containing the single required letter. You can use the functions you wrote in previous exercises.
# 4.  According to the "Spelling Bee" rules,
#
#   Four-letter words are worth 1 point each.
#
#   Longer words earn 1 point per letter.
#
#   Each puzzle includes at least one "pangram" which uses every letter. These are worth 7 extra points!
#
#   Write a function called score_word that takes a word and a string of available letters and returns its score. You can assume that the word is acceptable.
# 5.  If you got stuck on the previous question, try asking a virtual assistant, "Given a function, uses_only, which takes two strings and checks that the first uses only the letters in the second, use it to write uses_all, which takes two strings and checks whether the first uses all the letters in the second, allowing repeats."
#
#   Use run_doctests to check the answer.
# 6.  Now let's see if we can write uses_all based on uses_any.
#
#   Ask a virtual assistant, "Given a function, uses_any, which takes two strings and checks whether the first uses any of the letters in the second, can you use it to write uses_all, which takes two strings and checks whether the first uses all the letters in the second, allowing repeats."
#
#   If it says it can, be sure to test the result!

# %%
# Exercise 1
def uses_none(word, forbidden):
    """Checks whether a word avoid forbidden letters.

    >>> uses_none('banana', 'xyz')
    True
    >>> uses_none('apple', 'efg')
    False
    """
    for letter in word:
        if letter in forbidden:
            return False
    return True

run_doctests(uses_none)

# %%
# Exercise 2
def uses_all(word, required):
    """Checks whether a word uses all required letters.

    >>> uses_all('banana', 'ban')
    True
    >>> uses_all('apple', 'api')
    False
    """
    for letter in required:
        if letter not in word:
            return False
    return True
run_doctests(uses_all)

# %%
# Exercise 3
def check_word(word, available, required):
    """Check whether a word is acceptable.

    >>> check_word('color', 'ACDLORT', 'R')
    True
    >>> check_word('ratatat', 'ACDLORT', 'R')
    True
    >>> check_word('rat', 'ACDLORT', 'R')
    False
    >>> check_word('told', 'ACDLORT', 'R')
    False
    >>> check_word('bee', 'ACDLORT', 'R')
    False
    """
    for letter in word:
        if letter not in available:
            return False
    if not uses_all(word, required):
        return False
    return True
    run_doctests(check_word)

# %%
# Exercise 4
def word_score(word, available):
    """Compute the score for an acceptable word.

    >>> word_score('card', 'ACDLORT')
    1
    >>> word_score('color', 'ACDLORT')
    5
    >>> word_score('cartload', 'ACDLORT')
    15
    >>> word_score('ACDLORT', 'ACDLORT')
    14
    """
    score = 0
    if len(word) == 4:
        score = 1
    elif len(word) > 4:
        score = len(word)

    # Check for pangram
    is_pangram = True
    for letter in available.lower():
        if letter not in word.lower():
            is_pangram = False
            break

    if is_pangram:
        score += 7

    return score

run_doctests(word_score)

# %%
# Exercise 5
def uses_all(word, required):
    """Checks whether a word uses all required letters using uses_only.

    >>> uses_all('banana', 'ban')
    True
    >>> uses_all('apple', 'api')
    False
    >>> uses_all('programming', 'g')
    True
    """
    for letter in required.lower():
        if letter not in word.lower():
            return False
    return True

run_doctests(uses_all)
uses_all('programming', 'g')
# Out:
# True

# %%
# Exercise 6
def uses_any(word, letters):
    for letter in word.lower():
        if letter in letters.lower():
            return True
    return False
def uses_all(word, required):
    """Checks whether a word uses all required letters using uses_any.

    >>> uses_all('banana', 'ban')
    True
    >>> uses_all('apple', 'api')
    False
    >>> uses_all('programming', 'g')
    True
    >>> uses_all('double', 'bo')
    True
    """
    for letter in required.lower():
        if not uses_any(word.lower(), letter):
            return False
    return True
run_doctests(uses_all)
uses_all('apple', 'api')
# Out:
# False
